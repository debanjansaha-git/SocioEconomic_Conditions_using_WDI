# %%
# !pip install world_bank_data --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for world-bank-data: filename=world_bank_data-0.1.3-py3-none-any.whl size=11110 sha256=4379fb802737a699a1f83d4c619cd1df1bd776405766e512410e5a6bb4ebcbb8
#   Stored in directory: /root/.cache/pip/wheels/95/74/5e/c32dde16dc1ef8d8e9cf134ac93ae723ffec4f60be9c4873f5
# Successfully built world-bank-data
# ...

# %%
import os
import json
from datetime import datetime
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 10)

import world_bank_data as wb

# %%
wb.get_topics()
# Out:
#                               value  \
# id
# 1   Agriculture & Rural Development
# 2                 Aid Effectiveness
# 3                  Economy & Growth
# 4                         Education
# 5                   Energy & Mining
# ..                              ...
# 17                           Gender
# 18      Millenium development goals
# 19                   Climate Change
# 20                    External Debt
# 21                            Trade
#
#                                            sourceNote
# id
# 1   For the 70 percent of the world's poor who liv...
# 2   Aid effectiveness is the impact that aid has i...
# 3   Economic growth is central to economic develop...
# 4   Education is one of the most powerful instrume...
# 5   The world economy needs ever-increasing amount...
# ..                                                ...
# 17  Gender equality is a core development objectiv...
# 18
# 19  Climate change is expected to hit developing c...
# ...

# %%
wb.get_sources()
# Out:
#    lastupdated                                           name code  \
# id
# 1   2021-08-18                                 Doing Business  DBS
# 2   2022-09-16                   World Development Indicators  WDI
# 3   2022-09-23                Worldwide Governance Indicators  WGI
# 5   2016-03-21              Subnational Malnutrition Database  SNM
# 6   2022-01-14                  International Debt Statistics  IDS
# ..         ...                                            ...  ...
# 84  2022-07-19                               Education Policy  EDP
# 85  2022-11-03                                  PEFA_2021_SNG  SNG
# 86  2021-09-24         Global Jobs Indicators Database (JOIN)  JON
# 87  2022-10-07  Country Climate and Development Report (CCDR)  CCD
# 88  2022-07-05                      Food Prices for Nutrition  FPN
#
#    description url dataavailability metadataavailability concepts
# id
# 1                                 Y                    Y        3
# ...

# %%
wb.get_countries()
# Out:
#     iso2Code                                               name  \
# id
# ABW       AW                                              Aruba
# AFE       ZH                        Africa Eastern and Southern
# AFG       AF                                        Afghanistan
# AFR       A9                                             Africa
# AFW       ZI                         Africa Western and Central
# ..       ...                                                ...
# XZN       A5  Sub-Saharan Africa excluding South Africa and ...
# YEM       YE                                        Yemen, Rep.
# ZAF       ZA                                       South Africa
# ZMB       ZM                                             Zambia
# ZWE       ZW                                           Zimbabwe
#
#                          region  \
# id
# ABW  Latin America & Caribbean
# AFE                  Aggregates
# AFG                  South Asia
# AFR                  Aggregates
# ...

# %%
wb.get_regions()
# Out:
#    code iso2code                                               name
# id
#     AFE       ZH                        Africa Eastern and Southern
#     AFR       A9                                             Africa
#     AFW       ZI                         Africa Western and Central
#     ARB       1A                                         Arab World
#     CAA       C9            Sub-Saharan Africa (IFC classification)
# ..  ...      ...                                                ...
# 9   SSF       ZG                                Sub-Saharan Africa
#     SST       S1                                       Small states
#     SXZ       A4          Sub-Saharan Africa excluding South Africa
#     WLD       1W                                              World
#     XZN       A5  Sub-Saharan Africa excluding South Africa and ...
#
# [44 rows x 3 columns]

# %%
wb.get_incomelevels()
# Out:
#     iso2code                value
# id
# HIC       XD          High income
# INX       XY       Not classified
# LIC       XM           Low income
# LMC       XN  Lower middle income
# LMY       XO  Low & middle income
# MIC       XP        Middle income
# UMC       XT  Upper middle income

# %%
wb.get_lendingtypes()
# Out:
#     iso2code           value
# id
# IBD       XF            IBRD
# IDB       XH           Blend
# IDX       XI             IDA
# LNX       XX  Not classified

# %%
wb.get_indicators(topic=3, source=2)
# Out:
#                                                                 name unit  \
# id
# BG.GSR.NFSV.GD.ZS                       Trade in services (% of GDP)
# BM.GSR.CMCP.ZS     Communications, computer, etc. (% of service i...
# BM.GSR.FCTY.CD            Primary income payments (BoP, current US$)
# BM.GSR.GNFS.CD      Imports of goods and services (BoP, current US$)
# BM.GSR.INSF.ZS     Insurance and financial services (% of service...
# ...                                                              ...  ...
# NY.TTF.GNFS.KN              Terms of trade adjustment (constant LCU)
# PA.NUS.ATLS          DEC alternative conversion factor (LCU per US$)
# PA.NUS.PPP         PPP conversion factor, GDP (LCU per internatio...
# PA.NUS.PPPC.RF     Price level ratio of PPP conversion factor (GD...
# PA.NUS.PRVT.PP     PPP conversion factor, private consumption (LC...
#
#                                          source  \
# id
# BG.GSR.NFSV.GD.ZS  World Development Indicators
# ...

# %%
wb.search_indicators('GDP', source=2)
# Out:
#                                                                    name unit  \
# id
# BG.GSR.NFSV.GD.ZS                          Trade in services (% of GDP)
# BM.KLT.DINV.WD.GD.ZS  Foreign direct investment, net outflows (% of ...
# BN.CAB.XOKA.GD.ZS                    Current account balance (% of GDP)
# BX.KLT.DINV.WD.GD.ZS  Foreign direct investment, net inflows (% of GDP)
# BX.TRF.PWKR.DT.GD.ZS          Personal remittances, received (% of GDP)
# ...                                                                 ...  ...
# SH.STA.MMRT           Maternal mortality ratio (modeled estimate, pe...
# SH.XPD.CHEX.GD.ZS                 Current health expenditure (% of GDP)
# SH.XPD.GHED.GD.ZS     Domestic general government health expenditure...
# SL.GDP.PCAP.EM.KD         GDP per person employed (constant 2017 PPP $)
# TG.VAL.TOTL.GD.ZS                          Merchandise trade (% of GDP)
#
#                                             source  \
# id
# ...

# %%
pcap = pd.DataFrame(wb.get_series('SL.GDP.PCAP.EM.KD', date='1990:2022', id_or_value='id', simplify_index=True))
pcap
# Out:
#               SL.GDP.PCAP.EM.KD
# Country Year
# AFE     1990                NaN
#         1991        8244.518639
#         1992        7850.405134
#         1993        7582.666373
#         1994        7486.980479
# ...                         ...
# ZWE     2017        5228.429113
#         2018        5388.118118
#         2019        4969.081523
#         2020        4652.733381
#         2021        4775.607588
#
# [8512 rows x 1 columns]

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
wi_df = pd.read_csv('/content/drive/MyDrive/Northeastern/Projects/IE6600 Final Project/World Bank Selected Indicators - Sheet1.csv')

# %%
wi_df.head()
# Out:
#              Domain Category     Indicator Code  \
# 0  Economy & Growth      GDP  NY.GDP.MKTP.KD.ZG
# 1  Economy & Growth      GDP     GC.XPN.INTP.CN
# 2  Economy & Growth      GDP  GC.XPN.TOTL.GD.ZS
# 3  Economy & Growth      GDP  GC.DOD.TOTL.GD.ZS
# 4  Economy & Growth      GDP     NY.GDP.MKTP.CD
#
#                               Indicator Name  \
# 0                                 GDP Growth
# 1            Interest payments (current LCU)
# 2                         Expense (% of GDP)
# 3  Central government debt, total (% of GDP)
# 4                          GDP (current US$)
#
#                                          Source Note  Number of csv  \
# 0  Annual percentage growth rate of GDP at market...            1.0
# 1  Interest payments include interest payments on...            1.0
# 2  Expense is cash payments for operating activit...            1.0
# 3  Debt is the entire stock of direct government ...            1.0
# ...

# %%
indicatrs = list(wi_df['Indicator Code'].dropna().values)

# %%
indicatrs
# Out:
# ['NY.GDP.MKTP.KD.ZG',
#  'GC.XPN.INTP.CN',
#  'GC.XPN.TOTL.GD.ZS',
#  'GC.DOD.TOTL.GD.ZS',
#  'NY.GDP.MKTP.CD',
#  'NY.GDP.PCAP.CD',
#  'NY.GDP.PCAP.PP.CD',
#  'NY.GNS.ICTR.ZS',
#  'NY.GDP.DEFL.KD.ZG',
#  'GC.XPN.INTP.ZS',
#  'SL.UEM.TOTL.ZS',
#  'FP.CPI.TOTL.ZG',
#  'BX.KLT.DINV.CD.WD',
#  'FR.INR.LNDP',
#  'FR.INR.LEND',
#  'FM.LBL.BMNY.GD.ZS',
#  'CM.MKT.LCAP.GD.ZS',
#  'FS.AST.PRVT.GD.ZS',
#  'FS.AST.DOMS.GD.ZS',
#  'CM.MKT.TRAD.GD.ZS',
#  'NE.EXP.GNFS.ZS',
#  'NE.IMP.GNFS.ZS',
#  'SL.TLF.ACTI.ZS',
#  'IC.TAX.LABR.CP.ZS',
#  'EN.ATM.CO2E.PC',
#  'EG.ELC.RNWX.ZS',
#  'SH.STA.SMSS.ZS',
#  'AG.PRD.FOOD.XD',
#  'AG.LND.FRST.ZS']

# %%
wb.get_series(ind, date='1990:2022', id_or_value='id', simplify_index=True)
# Out:
# pandas.core.series.Series

# %%
data = pd.DataFrame()
for ind in indicatrs:
    data2 = wb.get_series(ind, date='1990:2022', id_or_value='id', simplify_index=True)
    data = pd.concat([data, data2], axis=1)

# %%
data.tail()
# Out:
#           NY.GDP.MKTP.KD.ZG  GC.XPN.INTP.CN  GC.XPN.TOTL.GD.ZS  \
# ZWE 2017           4.709492     229797540.0          28.413719
#     2018           4.824211     761307154.0          20.697183
#     2019          -6.144236             NaN                NaN
#     2020          -6.248748             NaN                NaN
#     2021           5.849420             NaN                NaN
#
#           GC.DOD.TOTL.GD.ZS  NY.GDP.MKTP.CD  ...  EN.ATM.CO2E.PC  \
# ZWE 2017                NaN    1.758489e+10  ...        0.726297
#     2018                NaN    1.811554e+10  ...        0.857411
#     2019                NaN    1.928429e+10  ...        0.802979
#     2020                NaN    1.805117e+10  ...             NaN
#     2021                NaN    2.621773e+10  ...             NaN
#
#           EG.ELC.RNWX.ZS  SH.STA.SMSS.ZS  AG.PRD.FOOD.XD  AG.LND.FRST.ZS
# ZWE 2017             NaN       26.576824          112.85       45.451183
# ...

# %% [markdown]
# United States. GDP – Nominal: $20.89 trillion.
#
# China. GDP – Nominal: $14.72 trillion.
#
# Japan. GDP – Nominal: $5.06 trillion.
#
# Germany. GDP – Nominal: $3.85 trillion.
#
# United Kingdom. GDP – Nominal: $2.76 trillion.
#
# India. GDP – Nominal: $2.66 trillion.
#
# France. GDP – Nominal: $2.63 trillion.

# %%
data.loc[('DEU', '2010'), :].isnull().sum()
# Out:
# 5

# %%
data.describe(include='all')
# Out:
#        NY.GDP.MKTP.KD.ZG  GC.XPN.INTP.CN  GC.XPN.TOTL.GD.ZS  \
# count        7750.000000    3.237000e+03        3700.000000
# mean            3.326760    1.180001e+12          27.096346
# std             5.860886    1.177478e+13          12.734016
# min           -64.047107   -3.364364e+09           0.000185
# 25%             1.377772    4.373000e+08          17.489232
# 50%             3.574575    7.303000e+09          25.790395
# 75%             5.774366    5.237600e+10          34.913989
# max           149.972963    3.140881e+14         210.205132
#
#        GC.DOD.TOTL.GD.ZS  NY.GDP.MKTP.CD  ...  EN.ATM.CO2E.PC  EG.ELC.RNWX.ZS  \
# count        1983.000000    7.922000e+03  ...     7144.000000     4761.000000
# mean           57.557790    1.719308e+12  ...        4.218163        2.480903
# std            36.953580    6.583730e+12  ...        5.197455        5.409203
# min            -1.170726    8.824448e+06  ...        0.000000        0.000000
# ...
