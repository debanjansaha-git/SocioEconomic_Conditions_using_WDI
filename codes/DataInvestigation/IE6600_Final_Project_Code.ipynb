# %% [markdown]
# # Introduction

# %%
# !pip install world_bank_data --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for world-bank-data: filename=world_bank_data-0.1.3-py3-none-any.whl size=11110 sha256=d3f2bc5d19647a1ade045ee5c316373cfd78080ec1865577b05f02a42673fb44
#   Stored in directory: /root/.cache/pip/wheels/fe/17/0c/9ef630351acc5856f4a1814d96bc082eccf1cbbb779fcd1a98
# Successfully built world-bank-data
# ...

# %%
import os
import json
from datetime import datetime
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 10)

import world_bank_data as wb

# %%
wb.get_topics()
# Out:
#                               value  \
# id
# 1   Agriculture & Rural Development
# 2                 Aid Effectiveness
# 3                  Economy & Growth
# 4                         Education
# 5                   Energy & Mining
# ..                              ...
# 17                           Gender
# 18      Millenium development goals
# 19                   Climate Change
# 20                    External Debt
# 21                            Trade
#
#                                            sourceNote
# id
# 1   For the 70 percent of the world's poor who liv...
# 2   Aid effectiveness is the impact that aid has i...
# 3   Economic growth is central to economic develop...
# 4   Education is one of the most powerful instrume...
# 5   The world economy needs ever-increasing amount...
# ..                                                ...
# 17  Gender equality is a core development objectiv...
# 18
# 19  Climate change is expected to hit developing c...
# ...

# %%
wb.get_sources()
# Out:
#    lastupdated                                           name code  \
# id
# 1   2021-08-18                                 Doing Business  DBS
# 2   2022-09-16                   World Development Indicators  WDI
# 3   2022-09-23                Worldwide Governance Indicators  WGI
# 5   2016-03-21              Subnational Malnutrition Database  SNM
# 6   2022-12-06                  International Debt Statistics  IDS
# ..         ...                                            ...  ...
# 84  2022-07-19                               Education Policy  EDP
# 85  2022-11-03                                  PEFA_2021_SNG  SNG
# 86  2021-09-24         Global Jobs Indicators Database (JOIN)  JON
# 87  2022-10-07  Country Climate and Development Report (CCDR)  CCD
# 88  2022-07-05                      Food Prices for Nutrition  FPN
#
#    description url dataavailability metadataavailability concepts
# id
# 1                                 Y                    Y        3
# ...

# %%
wb.get_countries()
# Out:
#     iso2Code                                               name  \
# id
# ABW       AW                                              Aruba
# AFE       ZH                        Africa Eastern and Southern
# AFG       AF                                        Afghanistan
# AFR       A9                                             Africa
# AFW       ZI                         Africa Western and Central
# ..       ...                                                ...
# XZN       A5  Sub-Saharan Africa excluding South Africa and ...
# YEM       YE                                        Yemen, Rep.
# ZAF       ZA                                       South Africa
# ZMB       ZM                                             Zambia
# ZWE       ZW                                           Zimbabwe
#
#                          region  \
# id
# ABW  Latin America & Caribbean
# AFE                  Aggregates
# AFG                  South Asia
# AFR                  Aggregates
# ...

# %%
wb.get_regions()
# Out:
#    code iso2code                                               name
# id
#     AFE       ZH                        Africa Eastern and Southern
#     AFR       A9                                             Africa
#     AFW       ZI                         Africa Western and Central
#     ARB       1A                                         Arab World
#     CAA       C9            Sub-Saharan Africa (IFC classification)
# ..  ...      ...                                                ...
# 9   SSF       ZG                                Sub-Saharan Africa
#     SST       S1                                       Small states
#     SXZ       A4          Sub-Saharan Africa excluding South Africa
#     WLD       1W                                              World
#     XZN       A5  Sub-Saharan Africa excluding South Africa and ...
#
# [44 rows x 3 columns]

# %%
wb.get_incomelevels()
# Out:
#     iso2code                value
# id
# HIC       XD          High income
# INX       XY       Not classified
# LIC       XM           Low income
# LMC       XN  Lower middle income
# LMY       XO  Low & middle income
# MIC       XP        Middle income
# UMC       XT  Upper middle income

# %%
wb.get_lendingtypes()
# Out:
#     iso2code           value
# id
# IBD       XF            IBRD
# IDB       XH           Blend
# IDX       XI             IDA
# LNX       XX  Not classified

# %%
wb.get_indicators(topic=3, source=2)
# Out:
#                                                                 name unit  \
# id
# BG.GSR.NFSV.GD.ZS                       Trade in services (% of GDP)
# BM.GSR.CMCP.ZS     Communications, computer, etc. (% of service i...
# BM.GSR.FCTY.CD            Primary income payments (BoP, current US$)
# BM.GSR.GNFS.CD      Imports of goods and services (BoP, current US$)
# BM.GSR.INSF.ZS     Insurance and financial services (% of service...
# ...                                                              ...  ...
# NY.TTF.GNFS.KN              Terms of trade adjustment (constant LCU)
# PA.NUS.ATLS          DEC alternative conversion factor (LCU per US$)
# PA.NUS.PPP         PPP conversion factor, GDP (LCU per internatio...
# PA.NUS.PPPC.RF     Price level ratio of PPP conversion factor (GD...
# PA.NUS.PRVT.PP     PPP conversion factor, private consumption (LC...
#
#                                          source  \
# id
# BG.GSR.NFSV.GD.ZS  World Development Indicators
# ...

# %%
wb.search_indicators('GDP', source=2)
# Out:
#                                                                    name unit  \
# id
# BG.GSR.NFSV.GD.ZS                          Trade in services (% of GDP)
# BM.KLT.DINV.WD.GD.ZS  Foreign direct investment, net outflows (% of ...
# BN.CAB.XOKA.GD.ZS                    Current account balance (% of GDP)
# BX.KLT.DINV.WD.GD.ZS  Foreign direct investment, net inflows (% of GDP)
# BX.TRF.PWKR.DT.GD.ZS          Personal remittances, received (% of GDP)
# ...                                                                 ...  ...
# SH.STA.MMRT           Maternal mortality ratio (modeled estimate, pe...
# SH.XPD.CHEX.GD.ZS                 Current health expenditure (% of GDP)
# SH.XPD.GHED.GD.ZS     Domestic general government health expenditure...
# SL.GDP.PCAP.EM.KD         GDP per person employed (constant 2017 PPP $)
# TG.VAL.TOTL.GD.ZS                          Merchandise trade (% of GDP)
#
#                                             source  \
# id
# ...

# %%
pcap = pd.DataFrame(wb.get_series('SL.GDP.PCAP.EM.KD', date='1990:2022', id_or_value='id', simplify_index=True))
pcap
# Out:
#               SL.GDP.PCAP.EM.KD
# Country Year
# AFE     1990                NaN
#         1991        8244.518639
#         1992        7850.405134
#         1993        7582.666373
#         1994        7486.980479
# ...                         ...
# ZWE     2017        5228.429113
#         2018        5388.118118
#         2019        4969.081523
#         2020        4652.733381
#         2021        4775.607588
#
# [8512 rows x 1 columns]

# %% [markdown]
# # start

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
wi_df = pd.read_csv('/content/drive/MyDrive/World Bank Selected Indicators - Sheet1.csv')

# %%
wi_df.head()
# Out:
#              Domain Category     Indicator Code  \
# 0  Economy & Growth      GDP  NY.GDP.MKTP.KD.ZG
# 1  Economy & Growth      GDP     GC.XPN.INTP.CN
# 2  Economy & Growth      GDP  GC.XPN.TOTL.GD.ZS
# 3  Economy & Growth      GDP  GC.DOD.TOTL.GD.ZS
# 4  Economy & Growth      GDP     NY.GDP.MKTP.CD
#
#                               Indicator Name  \
# 0                                 GDP Growth
# 1            Interest payments (current LCU)
# 2                         Expense (% of GDP)
# 3  Central government debt, total (% of GDP)
# 4                          GDP (current US$)
#
#                                          Source Note  Number of csv  \
# 0  Annual percentage growth rate of GDP at market...            1.0
# 1  Interest payments include interest payments on...            1.0
# 2  Expense is cash payments for operating activit...            1.0
# 3  Debt is the entire stock of direct government ...            1.0
# ...

# %%
indicatrs = list(wi_df['Indicator Code'].dropna().values)

# %%
indicatrs
# Out:
# ['NY.GDP.MKTP.KD.ZG',
#  'GC.XPN.INTP.CN',
#  'GC.XPN.TOTL.GD.ZS',
#  'GC.DOD.TOTL.GD.ZS',
#  'NY.GDP.MKTP.CD',
#  'NY.GDP.PCAP.CD',
#  'NY.GDP.PCAP.PP.CD',
#  'NY.GNS.ICTR.ZS',
#  'NY.GDP.DEFL.KD.ZG',
#  'GC.XPN.INTP.ZS',
#  'SL.UEM.TOTL.ZS',
#  'FP.CPI.TOTL.ZG',
#  'BX.KLT.DINV.CD.WD',
#  'FR.INR.LNDP',
#  'FR.INR.LEND',
#  'FM.LBL.BMNY.GD.ZS',
#  'CM.MKT.LCAP.GD.ZS',
#  'FS.AST.PRVT.GD.ZS',
#  'FS.AST.DOMS.GD.ZS',
#  'CM.MKT.TRAD.GD.ZS',
#  'NE.EXP.GNFS.ZS',
#  'NE.IMP.GNFS.ZS',
#  'SL.TLF.ACTI.ZS',
#  'IC.TAX.LABR.CP.ZS',
#  'EN.ATM.CO2E.PC',
#  'EG.ELC.RNWX.ZS',
#  'SH.STA.SMSS.ZS',
#  'AG.PRD.FOOD.XD',
#  'AG.LND.FRST.ZS',
#  'FS.AST.PRVT.GD.ZS',
#  'TG.VAL.TOTL.GD.ZS',
#  'GC.DOD.TOTL.GD.ZS',
#  'GC.XPN.TOTL.GD.ZS',
#  'MS.MIL.XPND.GD.ZS',
#  'GC.AST.TOTL.GD.ZS',
#  'GC.LBL.TOTL.GD.ZS',
#  'GC.NFN.TOTL.GD.ZS',
#  'GC.NLD.TOTL.GD.ZS',
#  'GC.REV.XGRT.GD.ZS',
#  'GC.TAX.TOTL.GD.ZS',
#  'GB.XPD.RSDV.GD.ZS',
#  'TG.VAL.TOTL.GD.ZS',
#  'SE.XPD.TOTL.GD.ZS',
#  'SE.XPD.PRIM.PC.ZS',
# ...

# %%
data = pd.DataFrame()
for ind in indicatrs:
    data2 = wb.get_series(ind, date='1990:2022', id_or_value='id', simplify_index=True)
    data = pd.concat([data, data2], axis=1)

# %%
data.tail()
# Out:
#           NY.GDP.MKTP.KD.ZG  GC.XPN.INTP.CN  GC.XPN.TOTL.GD.ZS  \
# ZWE 2017           4.709492     229797540.0          28.413719
#     2018           4.824211     761307154.0          20.697183
#     2019          -6.144236             NaN                NaN
#     2020          -6.248748             NaN                NaN
#     2021           5.849420             NaN                NaN
#
#           GC.DOD.TOTL.GD.ZS  NY.GDP.MKTP.CD  ...  SH.IMM.MEAS  \
# ZWE 2017                NaN    1.758489e+10  ...         90.0
#     2018                NaN    1.811554e+10  ...         88.0
#     2019                NaN    1.928429e+10  ...         85.0
#     2020                NaN    1.805117e+10  ...         85.0
#     2021                NaN    2.621773e+10  ...         85.0
#
#           SP.POP.1564.TO.ZS  SP.POP.1564.TO.ZS  SL.TLF.TOTL.IN  SP.POP.1564.TO
# ZWE 2017          54.505941          54.505941       6909356.0       7759792.0
# ...

# %% [markdown]
# United States. GDP – Nominal: $20.89 trillion.
#
# China. GDP – Nominal: $14.72 trillion.
#
# Japan. GDP – Nominal: $5.06 trillion.
#
# Germany. GDP – Nominal: $3.85 trillion.
#
# United Kingdom. GDP – Nominal: $2.76 trillion.
#
# India. GDP – Nominal: $2.66 trillion.
#
# France. GDP – Nominal: $2.63 trillion.

# %%
data.describe(include='all')
# Out:
#        NY.GDP.MKTP.KD.ZG  GC.XPN.INTP.CN  GC.XPN.TOTL.GD.ZS  \
# count        7750.000000    3.237000e+03        3700.000000
# mean            3.326760    1.180001e+12          27.096346
# std             5.860886    1.177478e+13          12.734016
# min           -64.047107   -3.364364e+09           0.000185
# 25%             1.377772    4.373000e+08          17.489232
# 50%             3.574575    7.303000e+09          25.790395
# 75%             5.774366    5.237600e+10          34.913989
# max           149.972963    3.140881e+14         210.205132
#
#        GC.DOD.TOTL.GD.ZS  NY.GDP.MKTP.CD  ...  SH.IMM.MEAS  SP.POP.1564.TO.ZS  \
# count        1983.000000    7.922000e+03  ...  7568.000000        7734.000000
# mean           57.557790    1.719308e+12  ...    82.665771          61.705652
# std            36.953580    6.583730e+12  ...    16.255159           6.816566
# min            -1.170726    8.824448e+06  ...     8.000000          45.895852
# ...

# %% [markdown]
# ## Countries finding
# editor:Zeyuan Liu

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def calculate_quality(data,rate):
  not_good_list = []
  for i in range(data.shape[1]):
    if (sum(data.iloc[:,i].isna())/len(data.iloc[:,i])) >rate:
      #print(f'{data.columns[i]}:{(sum(data.iloc[:,i].isna())/len(data.iloc[:,i]))}')
      not_good_list.append(data.columns[i])
  #print(f'There are {len(not_good_list)} columns with missing value rate larger than {100*rate}%')
  return len(not_good_list)

# %%
countries = wb.get_countries()
countries['incomeLevel'].value_counts()
countries = countries[(countries['incomeLevel'] != 'Low income') & (countries['incomeLevel'] != 'Not classified')]

# %% [markdown]
# ### East Asia & Pacific

# %%
EAP = countries[countries['region'] == 'East Asia & Pacific']

# %%
EAP = EAP.dropna(subset = ['longitude','latitude'])

# %%
EAP_iso = list(EAP['iso2Code'])
EAP_3abb = list(EAP.index)

# %%
contries_list = []
missing_column_list = []
for ele in EAP_3abb:
  contries_list.append(ele)
  missing_column_list.append(calculate_quality(data.loc[[ele],:,:],0.1))
fig,ax = plt.subplots(1,1,figsize = (16,9))
ax.plot(contries_list,missing_column_list)

# %%
EAP_chosen = ['AUS','KOR','PHL','SGP','THA']

# %% [markdown]
# ### Europe & Central Asia

# %%
ECA = countries[countries['region'] == 'Europe & Central Asia']
ECA = ECA.dropna(subset = ['longitude','latitude'])
ECA_iso = list(ECA['iso2Code'])
ECA_3abb = list(ECA.index)

# %%
contries_list = []
missing_column_list = []
for ele in ECA_3abb:
  contries_list.append(ele)
  missing_column_list.append(calculate_quality(data.loc[[ele],:,:],0.1))
fig,ax = plt.subplots(1,1,figsize = (24,5))
ax.plot(contries_list,missing_column_list)
ax.plot(contries_list,[30 for i in range(len(contries_list))])

# %%
ECA_chosen = ['GBR','HUN','ROU','SWE']

# %% [markdown]
# ### Latin America & Caribbean

# %%
LAC_bool = []
for i in countries['region']:
  if 'Latin America' in i:
    LAC_bool.append(True)
  else:
    LAC_bool.append(False)
LAC = countries[LAC_bool]
LAC = LAC.dropna(subset = ['longitude','latitude'])
LAC_iso = list(LAC['iso2Code'])
LAC_3abb = list(LAC.index)

# %%
contries_list = []
missing_column_list = []
for ele in LAC_3abb:
  contries_list.append(ele)
  missing_column_list.append(calculate_quality(data.loc[[ele],:,:],0.1))
fig,ax = plt.subplots(1,1,figsize = (16,9))
ax.plot(contries_list,missing_column_list)
ax.plot(contries_list,[30 for i in range(len(contries_list))])

# %%
calculate_quality(data.loc[['USA'],:,:],0)

# %%
LAC_chosen = ['JAM','PER']

# %% [markdown]
# ### Middle East & North Africa

# %%
MENA = countries[countries['region'] == 'Middle East & North Africa']
MENA = MENA.dropna(subset = ['longitude','latitude'])
MENA_iso = list(MENA['iso2Code'])
MENA_3abb = list(MENA.index)

contries_list = []
missing_column_list = []
for ele in MENA_3abb:
  contries_list.append(ele)
  missing_column_list.append(calculate_quality(data.loc[[ele],:,:],0.1))
fig,ax = plt.subplots(1,1,figsize = (16,9))
ax.plot(contries_list,missing_column_list)
ax.plot(contries_list,[30 for i in range(len(contries_list))])

# %%
MENA_chosen = ['JOR']

# %% [markdown]
# ### North America

# %%
NA = countries[countries['region'] == 'North America']
NA = NA.dropna(subset = ['longitude','latitude'])
NA_iso = list(NA['iso2Code'])
NA_3abb = list(NA.index)

contries_list = []
missing_column_list = []
for ele in NA_3abb:
  contries_list.append(ele)
  missing_column_list.append(calculate_quality(data.loc[[ele],:,:],0.1))
fig,ax = plt.subplots(1,1,figsize = (16,9))
ax.plot(contries_list,missing_column_list)
ax.plot(contries_list,[30 for i in range(len(contries_list))])

# %%
NA_chosen = ['USA']

# %% [markdown]
# ### South Asia

# %%
SA = countries[countries['region'] == 'South Asia']
SA = SA.dropna(subset = ['longitude','latitude'])
SA_iso = list(SA['iso2Code'])
SA_3abb = list(SA.index)

contries_list = []
missing_column_list = []
for ele in SA_3abb:
  contries_list.append(ele)
  missing_column_list.append(calculate_quality(data.loc[[ele],:,:],0.1))
fig,ax = plt.subplots(1,1,figsize = (16,9))
ax.plot(contries_list,missing_column_list)
ax.plot(contries_list,[30 for i in range(len(contries_list))])

# %%
SA_chosen = ['IND']

# %% [markdown]
# ### chosen test

# %%
chosen = EAP_chosen + ECA_chosen + LAC_chosen + MENA_chosen + NA_chosen + SA_chosen
chosen
# Out:
# ['AUS',
#  'KOR',
#  'PHL',
#  'SGP',
#  'THA',
#  'GBR',
#  'HUN',
#  'ROU',
#  'SWE',
#  'JAM',
#  'PER',
#  'JOR',
#  'USA',
#  'IND']

# %%
chosen_data = data.loc[chosen,:,:]
chosen_data
# Out:
#           NY.GDP.MKTP.KD.ZG  GC.XPN.INTP.CN  GC.XPN.TOTL.GD.ZS  \
# AUS 1990           3.573507    7.364000e+09          21.822977
#     1991          -0.395087    6.192000e+09          23.171087
#     1992           0.413780    5.748000e+09          24.439892
#     1993           4.033567    5.413000e+09          24.969497
#     1994           3.980474    6.630000e+09          25.092045
# ...                     ...             ...                ...
# IND 2017           6.795383    5.292460e+12          15.614110
#     2018           6.453851    5.741910e+12          15.663132
#     2019           3.737919             NaN                NaN
#     2020          -6.596081             NaN                NaN
#     2021           8.947963             NaN                NaN
#
#           GC.DOD.TOTL.GD.ZS  NY.GDP.MKTP.CD  ...  SH.IMM.MEAS  \
# AUS 1990          12.231535    3.113267e+11  ...         86.0
#     1991          11.921499    3.259030e+11  ...         86.0
# ...

# %%
import seaborn as sns
plt.figure(figsize=(50,200))
sns.displot(
    data=chosen_data.iloc[:,:].isna().melt(value_name="missing"),
    y="variable",
    hue="missing",
    multiple="fill",
    aspect=1.25
)
plt.plot(range(chosen_data.shape[1]),[0.1 for i in range(chosen_data.shape[1])],color = 'r')
plt.savefig("visualizing_missing_data_with_barplot_Seaborn_distplot.png", dpi=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-749208220d95> in <module>
#       1 import seaborn as sns
# ----> 2 plt.figure(figsize=(50,200))
#       3 sns.displot(
#       4     data=chosen_data.iloc[:,:].isna().melt(value_name="missing"),
#       5     y="variable",
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=(30,18))
sns.displot(
    data=chosen_data.iloc[:,0:25].isna().melt(value_name="missing"),
    y="variable",
    hue="missing",
    multiple="fill",
    aspect=1.25
)
plt.savefig("visualizing_missing_data_with_barplot_Seaborn_distplot.png", dpi=100)

# %%
plt.figure(figsize=(30,18))
sns.displot(
    data=chosen_data.iloc[:,25:50].isna().melt(value_name="missing"),
    y="variable",
    hue="missing",
    multiple="fill",
    aspect=1.25
)
plt.savefig("visualizing_missing_data_with_barplot_Seaborn_distplot.png", dpi=100)

# %%
plt.figure(figsize=(30,18))
sns.displot(
    data=chosen_data.iloc[:,50:75].isna().melt(value_name="missing"),
    y="variable",
    hue="missing",
    multiple="fill",
    aspect=1.25
)
plt.savefig("visualizing_missing_data_with_barplot_Seaborn_distplot.png", dpi=100)

# %%
plt.figure(figsize=(50,200))
sns.displot(
    data=chosen_data.iloc[:,75:].isna().melt(value_name="missing"),
    y="variable",
    hue="missing",
    multiple="fill",
    aspect=1.25
)
plt.savefig("visualizing_missing_data_with_barplot_Seaborn_distplot.png", dpi=100)

# %%
def calculate_quality(data,rate):
  not_good_list = []
  for i in range(data.shape[1]):
    if (sum(data.iloc[:,i].isna())/len(data.iloc[:,i])) >rate:
      #print(f'{data.columns[i]}:{(sum(data.iloc[:,i].isna())/len(data.iloc[:,i]))}')
      not_good_list.append(data.columns[i])
  print(f'There are {len(not_good_list)} columns with missing value rate larger than {100*rate}%')
  return not_good_list

# %%
drop_list_country= calculate_quality(chosen_data ,0.2)

# %%
chosen_data_d = chosen_data.drop(drop_list_country, axis=1)
na_columns = chosen_data_d.columns[chosen_data_d.isnull().any()]

# %%
plt.figure(figsize=(30,18))
sns.displot(
    data=chosen_data_d.loc[:,na_columns[0:25]].isna().melt(value_name="missing"),
    y="variable",
    hue="missing",
    multiple="fill",
    aspect=1.25
)
plt.savefig("visualizing_missing_data_with_barplot_Seaborn_distplot.png", dpi=100)

# %%
plt.figure(figsize=(30,18))
sns.displot(
    data=chosen_data_d.loc[:,na_columns[25:]].isna().melt(value_name="missing"),
    y="variable",
    hue="missing",
    multiple="fill",
    aspect=1.25
)
plt.savefig("visualizing_missing_data_with_barplot_Seaborn_distplot.png", dpi=100)

# %%
for c in chosen:
  print(c, chosen_data_d.loc[c ,'EN.ATM.CO2E.PC'].isna().sum())

# %%
for c in chosen:
  print(c, chosen_data_d.loc[c ,'CM.MKT.TRAD.GD.ZS'].isna().sum())

# %%
for c in chosen:
  print(c, chosen_data_d.loc[c ,'EG.ELC.RNWX.ZS'].isna().sum())

# %%
for c in chosen:
  print(c, chosen_data_d.loc[c ,'GC.DOD.TOTL.GD.ZS'].isna().sum())

# %%
for c in chosen:
  print(c, chosen_data_d.loc[c ,'BN.TRF.KOGT.CD'].isna().sum())

# %%
for c in chosen:
  print(c, chosen_data_d.loc[c ,'GC.LBL.TOTL.GD.ZS'].isna().sum())

# %%
for c in chosen:
  print(c, chosen_data_d.loc[c ,'GC.XPN.INTP.CN'].isna().sum())

# %%
for c in chosen:
  chosen_data_d_i = chosen_data_d.interpolate()

# %% [markdown]
# # Data cleaning
# editor: Zeyuan Liu

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# **Attention: this is path of Zeyuan's drive**\
# **If you run this cell, it will return error on your own drive**

# %%
wi_df = pd.read_csv('/content/drive/MyDrive/World Bank Selected Indicators - Sheet1.csv')

# %%
wi_df.head()
# Out:
#              Domain Category     Indicator Code  \
# 0  Economy & Growth      GDP  NY.GDP.MKTP.KD.ZG
# 1  Economy & Growth      GDP     GC.XPN.INTP.CN
# 2  Economy & Growth      GDP  GC.XPN.TOTL.GD.ZS
# 3  Economy & Growth      GDP  GC.DOD.TOTL.GD.ZS
# 4  Economy & Growth      GDP     NY.GDP.MKTP.CD
#
#                               Indicator Name  \
# 0                                 GDP Growth
# 1            Interest payments (current LCU)
# 2                         Expense (% of GDP)
# 3  Central government debt, total (% of GDP)
# 4                          GDP (current US$)
#
#                                          Source Note  Number of csv  \
# 0  Annual percentage growth rate of GDP at market...            1.0
# 1  Interest payments include interest payments on...            1.0
# 2  Expense is cash payments for operating activit...            1.0
# 3  Debt is the entire stock of direct government ...            1.0
# ...

# %%
indicatrs = list(wi_df['Indicator Code'].dropna().values)
indicatrs
# Out:
# ['NY.GDP.MKTP.KD.ZG',
#  'GC.XPN.INTP.CN',
#  'GC.XPN.TOTL.GD.ZS',
#  'GC.DOD.TOTL.GD.ZS',
#  'NY.GDP.MKTP.CD',
#  'NY.GDP.PCAP.CD',
#  'NY.GDP.PCAP.PP.CD',
#  'NY.GNS.ICTR.ZS',
#  'NY.GDP.DEFL.KD.ZG',
#  'GC.XPN.INTP.ZS',
#  'SL.UEM.TOTL.ZS',
#  'FP.CPI.TOTL.ZG',
#  'BX.KLT.DINV.CD.WD',
#  'FR.INR.LNDP',
#  'FR.INR.LEND',
#  'FM.LBL.BMNY.GD.ZS',
#  'CM.MKT.LCAP.GD.ZS',
#  'FS.AST.PRVT.GD.ZS',
#  'FS.AST.DOMS.GD.ZS',
#  'CM.MKT.TRAD.GD.ZS',
#  'NE.EXP.GNFS.ZS',
#  'NE.IMP.GNFS.ZS',
#  'SL.TLF.ACTI.ZS',
#  'IC.TAX.LABR.CP.ZS',
#  'EN.ATM.CO2E.PC',
#  'EG.ELC.RNWX.ZS',
#  'SH.STA.SMSS.ZS',
#  'AG.PRD.FOOD.XD',
#  'AG.LND.FRST.ZS',
#  'FS.AST.PRVT.GD.ZS',
#  'TG.VAL.TOTL.GD.ZS',
#  'GC.DOD.TOTL.GD.ZS',
#  'GC.XPN.TOTL.GD.ZS',
#  'MS.MIL.XPND.GD.ZS',
#  'GC.AST.TOTL.GD.ZS',
#  'GC.LBL.TOTL.GD.ZS',
#  'GC.NFN.TOTL.GD.ZS',
#  'GC.NLD.TOTL.GD.ZS',
#  'GC.REV.XGRT.GD.ZS',
#  'GC.TAX.TOTL.GD.ZS',
#  'GB.XPD.RSDV.GD.ZS',
#  'TG.VAL.TOTL.GD.ZS',
#  'SE.XPD.TOTL.GD.ZS',
#  'SE.XPD.PRIM.PC.ZS',
# ...

# %%
data = pd.DataFrame()
for ind in indicatrs:
    data2 = wb.get_series(ind, date='1990:2022', id_or_value='id', simplify_index=True)
    data = pd.concat([data, data2], axis=1)

# %%
data.head(2)
# Out:
#           NY.GDP.MKTP.KD.ZG  GC.XPN.INTP.CN  GC.XPN.TOTL.GD.ZS  \
# AFE 1990          -0.039677             NaN                NaN
#     1991           0.105301             NaN                NaN
#
#           GC.DOD.TOTL.GD.ZS  NY.GDP.MKTP.CD  ...  SH.IMM.MEAS  \
# AFE 1990                NaN    2.532240e+11  ...    59.305126
#     1991                NaN    2.734028e+11  ...    53.933170
#
#           SP.POP.1564.TO.ZS  SP.POP.1564.TO.ZS  SL.TLF.TOTL.IN  SP.POP.1564.TO
# AFE 1990          51.430660          51.430660     120062718.0     156682481.0
#     1991          51.477748          51.477748     123616494.0     161328531.0
#
# [2 rows x 101 columns]

# %%
data.shape
# Out:
# (8512, 101)

# %% [markdown]
# **calculate number of missing values of every columns**

# %%
def calculate_quality(data,rate):
  not_good_list = []
  for i in range(data.shape[1]):
    if (sum(data.iloc[:,i].isna())/len(data.iloc[:,i])) >rate:
      #print(f'{data.columns[i]}:{(sum(data.iloc[:,i].isna())/len(data.iloc[:,i]))}')
      not_good_list.append(data.columns[i])
  print(f'There are {len(not_good_list)} columns with missing value rate larger than {100*rate}%')
  return not_good_list

# %%
x = calculate_quality(data,0.2)
# Out:
# There are 84 columns with missing value rate larger than 10.0%

# %%
x = calculate_quality(data,0.2)
# Out:
# There are 61 columns with missing value rate larger than 20.0%

# %%
x = calculate_quality(data,0.3)
# Out:
# There are 58 columns with missing value rate larger than 30.0%

# %% [markdown]
# ## if we only care about the largest 7 countries in the world

# %%
data7 = data.loc[['USA','CHN','JPN','DEU','GBR','IND','FRA'],:,:]

# %%
drop_list = calculate_quality(data7,0.1)
# Out:
# There are 47 columns with missing value rate larger than 10.0%

# %%
x = calculate_quality(data7,0.2)
# Out:
# There are 33 columns with missing value rate larger than 20.0%

# %% [markdown]
# ## if we only care about the data of the largest 7 countries in the world during the period from 2000 to 2020

# %%
data7_limited = data7.loc[:,[str(i) for i in range(2000,2021)],:]

# %%
x = calculate_quality(data7_limited,0.1)
# Out:
# There are 40 columns with missing value rate larger than 10.0%

# %% [markdown]
# # colusion
# editor:Zeyuan Liu

# %% [markdown]
# <font color = 'red'>**We had better drop 40 columns among 101 columns becuase of too much missing value**</font>

# %%
drop_list
# Out:
# ['GC.XPN.INTP.CN',
#  'GC.XPN.TOTL.GD.ZS',
#  'GC.DOD.TOTL.GD.ZS',
#  'GC.XPN.INTP.ZS',
#  'FR.INR.LNDP',
#  'FR.INR.LEND',
#  'FM.LBL.BMNY.GD.ZS',
#  'CM.MKT.LCAP.GD.ZS',
#  'FS.AST.PRVT.GD.ZS',
#  'FS.AST.DOMS.GD.ZS',
#  'CM.MKT.TRAD.GD.ZS',
#  'IC.TAX.LABR.CP.ZS',
#  'EG.ELC.RNWX.ZS',
#  'SH.STA.SMSS.ZS',
#  'FS.AST.PRVT.GD.ZS',
#  'GC.DOD.TOTL.GD.ZS',
#  'GC.XPN.TOTL.GD.ZS',
#  'GC.AST.TOTL.GD.ZS',
#  'GC.LBL.TOTL.GD.ZS',
#  'GC.NFN.TOTL.GD.ZS',
#  'GC.NLD.TOTL.GD.ZS',
#  'GC.REV.XGRT.GD.ZS',
#  'GC.TAX.TOTL.GD.ZS',
#  'GB.XPD.RSDV.GD.ZS',
#  'SE.XPD.TOTL.GD.ZS',
#  'SE.XPD.PRIM.PC.ZS',
#  'SE.XPD.SECO.PC.ZS',
#  'SE.XPD.TERT.PC.ZS',
#  'DT.DOD.DECT.GN.ZS',
#  'DT.DOD.DPNG.CD',
#  'DT.DOD.DPPG.CD',
#  'DT.DOD.DECT.CD',
#  'EN.POP.EL5M.ZS',
#  'SI.POV.DDAY',
#  'EN.ATM.PM25.MC.ZS',
#  'EN.POP.EL5M.ZS',
#  'EN.POP.SLUM.UR.ZS',
#  'SI.SPR.PC40',
#  'SI.SPR.PCAP.ZG',
#  'SI.SPR.PC40.ZG',
#  'SI.SPR.PCAP',
#  'BX.GRT.EXTA.CD.WD',
#  'NY.EXP.CAPM.KN',
#  'NE.EXP.GNFS.KD.ZG',
# ...

# %%
data7_after_dropping = data7.drop(drop_list,axis = 1)

# %% [markdown]
# <font color = 'red'>**Now we get the dataframe with less missing value**

# %%
data7_after_dropping.shape
# Out:
# (224, 54)

# %% [markdown]
# <font color = 'red'>**Now we get the dataframe without any missing value**

# %%
data7_after_dropping.dropna().shape
# Out:
# (168, 54)

# %% [markdown]
# # Task3: data prediction
# editor:Zeyuan Liu

# %% [markdown]
# ## Prediction based on time Series itself

# %% [markdown]
# ### linear regression

# %% [markdown]
# ### logistics regression

# %% [markdown]
# ### regression tree

# %% [markdown]
# ## Prediction based on future features(not recommended)
